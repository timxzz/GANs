# %%
# import scipy.misc
# scipy.misc.imsave('outfile.jpg', image_array)

from PIL import Image
import glob
import numpy as np

def convert_image():
#     for filename in glob.iglob('../assets/**/**/*.bmp', recursive=True):
    for filename in glob.iglob('../assets_ae/cbegan_exprs_2_gamma_0.5_expr_crop_64/**/*.bmp', recursive=True):
        print(filename)
# im = Image.open("/Users/Hugo/green_leaves.jpg")
# p = np.array(im)
# im = Image.fromarray(A)
# im.save("your_file.jpeg")

convert_image()
# Out:
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/4879_434004122323_output.bmp
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/9759_251301364154_output.bmp
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/2439_156436463613_output.bmp
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/21959_023300455130_output.bmp
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/12199_166136010161_output.bmp
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/14639_141110552543_output.bmp
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/24399_321456015266_output.bmp
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/19519_263635601603_output.bmp
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/17079_502643612510_output.bmp
# ../assets/cbegan_exprs_2_gamma_0.5_expr_crop_64/result/7319_362112436324_output.bmp

# %%
import cv2
import glob
import numpy as np
import os

def find_image():
    files = glob.glob("Faces_with_expression_label/dataset_128x128/*.jpg")
    
    for f in files:
        fname = f.split("/")[-1]
        name_array = fname.split("_")
        image_num = int(name_array[0])
        if image_num  < 578:
            continue
        frame = cv2.imread(f) #Open image
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) #Convert image to grayscale
        
        intensity = np.sum(gray) / (128.*128.)
        if intensity > 110.:
            pathname = os.path.abspath(f)
#             os.remove(pathname) !!!!!!!!!! REMOVE
            print(pathname + ' ----- ' + str(intensity))
        
find_image()
# Out:
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_128x128/0595_6.jpg ----- 117.052185059
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_128x128/0629_2.jpg ----- 129.522338867
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_128x128/0627_6.jpg ----- 114.739013672
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_128x128/0629_0.jpg ----- 110.047607422

# %%
import cv2
import glob
import numpy as np
import os

def remove_FL_FR_image():
    files = glob.glob("Faces_with_expression_label/dataset_64x64_KDEF_side_face/*.jpg")
    
    for f in files:
        fname = f.split("/")[-1]
        name_array = fname.split("_")
        image_num = int(name_array[0])
        if image_num >= 718 and image_num <=984:
            pathname = os.path.abspath(f)
#             os.remove(pathname)
            print(pathname)

        
remove_FL_FR_image()
# Out:
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_64x64_KDEF_side_face/0888_6.jpg
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_64x64_KDEF_side_face/0914_2.jpg
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_64x64_KDEF_side_face/0851_4.jpg
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_64x64_KDEF_side_face/0810_6.jpg
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_64x64_KDEF_side_face/0736_6.jpg
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_64x64_KDEF_side_face/0749_4.jpg
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_64x64_KDEF_side_face/0984_0.jpg
# /home/tim/Workspace/ML/GANs/Face/Face_data/Faces_with_expression_label/dataset_64x64_KDEF_side_face/0724_0.jpg
# ...

# %%
import cv2
import glob

faceDet = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
faceDet_two = cv2.CascadeClassifier("haarcascade_frontalface_alt2.xml")
faceDet_three = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
faceDet_four = cv2.CascadeClassifier("haarcascade_frontalface_alt_tree.xml")

def detect_faces():
    
    # For expr data from Tim
    files = glob.glob("Faces_with_expression_label/dataset_128x128_KDEF_HLR/*") # first set


    #filenumber = 0
    for f in files:
        
        frame = cv2.imread(f) #Open image
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) #Convert image to grayscale
        color_for_detection = gray
        
        #Detect face using 4 different classifiers
        face = faceDet.detectMultiScale(color_for_detection, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)
        face_two = faceDet_two.detectMultiScale(color_for_detection, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)
        face_three = faceDet_three.detectMultiScale(color_for_detection, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)
        face_four = faceDet_four.detectMultiScale(color_for_detection, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)

        #Go over detected faces, stop at first detected face, return empty if no face.
        if len(face) == 1:
            facefeatures = face
        elif len(face_two) == 1:
            facefeatures = face_two
        elif len(face_three) == 1:
            facefeatures = face_three
        elif len(face_four) == 1:
            facefeatures = face_four
        else:
            print("face not found in file: %s" %f)
        

detect_faces()
# Out:
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/770_6.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/942_2.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/837_6.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/827_1.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/972_4.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/817_0.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/893_2.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/801_0.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/829_1.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/872_6.jpg
# face not found in file: Faces_with_expression_label/dataset_128x128_KDEF_HLR/856_0.jpg
# ...
